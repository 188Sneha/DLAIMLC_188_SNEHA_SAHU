# %%
import tensorflow as tf
import numpy as np

#Step 1: Convert data to NumPy arrays
x = np.array([1,2,3,4], dtype=float)
y = np.array([2,4,6,8], dtype=float)

#Step 2: Define model using Input layer (recommended)
model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),   #preffered over input_shape in Dense
    tf.keras.layers.Dense(1)
])

#Step 3: Compile the model
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

#Step 4: Train the model
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 4.8203
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 3.3477
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.3259
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.6168
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.1248
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.7834
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.5465
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.3821
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.2680
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1888

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#Convert lists to Numpy array
x = np.array([1,2,3,4], dtype=float)
y = np.array([2,4,6,8], dtype=float)

#Define the model
model = Sequential([
    Dense(1, input_shape=(1,))   #This works or you can use tf.keras.Input
])

#Compile the model
model.compile(optimizer='sgd', loss='mse')

#Train the model
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - loss: 95.5933
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 66.3896
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 46.1253
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 32.0641
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 22.3069
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 15.5363
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - loss: 10.8379
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 7.5775
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 5.3148
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 3.7444

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#Define a simple linear model
model = nn.Linear(1,1)

#Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

#Dummy data
x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

#Training loop
for epoch in range(10):
  optimizer.zero_grad()
  outputs = model(x)
  loss = criterion(outputs, y)
  loss.backward()
  optimizer.step()
  print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 17.593393325805664
# Epoch 2, Loss: 12.29807186126709
# Epoch 3, Loss: 8.623218536376953
# Epoch 4, Loss: 6.07277774810791
# Epoch 5, Loss: 4.302548408508301
# Epoch 6, Loss: 3.0736920833587646
# Epoch 7, Loss: 2.2204864025115967
# Epoch 8, Loss: 1.6279408931732178
# Epoch 9, Loss: 1.2162646055221558
# Epoch 10, Loss: 0.9300934076309204
